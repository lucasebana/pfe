# %%
# https://github.com/ashish-gehani/SPADE/wiki/Reporting-provenance-using-JSON

#ISMAGS.largest_common_subgraph

import json
import networkx as nx
from random import randrange

# %%
data = []
with open('fork.audit.log') as f:
    for line in f:
        data.append(json.loads(line))

# %%
G = nx.MultiDiGraph()
Nodes = []
Edges = []

# %%
for i in range(len(data)):
    if data[i]["type"] in ["Entity","Activity","Agent"]:
        Nodes.append(data[i])
    elif data[i]["type"] in ["ActedOnBehalfOf","WasInformedBy","WasDerivedFrom","WasAssociatedWith","WasAttributedTo","Used","WasGeneratedBy"]:
        Edges.append(data[i])

# %%
node_types = ["unknown","string","task","inode_unknown","link","file","directory","char","block","pipe","socket","msg","shm","address","sb","path","disc_entity","disc_activity","disc_agent","machine","packet","iattr","xattr","packet_content","argv","envp","process_memory"]

# %%
ObjectIds = []
for i in range(len(Nodes)):
    if(Nodes[i]["annotations"]["object_id"] not in ObjectIds):
        ObjectIds.append(Nodes[i]["annotations"]["object_id"])
# Out:
# {'type': 'Activity', 'id': 'AQAAAAAAAEDXywEAAAAAABQAAADuv4NsAQAAAAAAAAA=', 'annotations': {'object_id': '117719', 'object_type': 'task', 'boot_id': 20, 'cf:machine_id': 'cf:1820573678', 'version': 1, 'cf:date': '2023:01:08T09:07:14', 'epoch': 2, 'pid': 2395, 'vpid': 2395, 'utime': '6121', 'stime': '5319', 'vm': '2632', 'rss': '880', 'hw_vm': '2720', 'hw_rss': '880', 'rbytes': '57344', 'wbytes': '0', 'cancel_wbytes': '0', 'secctx': 'system_u:object_r:unlabeled_t:s0'}}

# %%
for i in range(len(Nodes)):
    N = Nodes
    NiA = Nodes[i]["annotations"]
    '''
    G.add_node(N[i]["id"],
    label=NiA["object_type"],
    group=node_types.index(NiA["object_type"]),
    type=N[i]["type"],
    objectid=NiA["object_id"],
    objecttype=NiA["object_type"],
    shape="box")
    '''
    G.add_node(N[i]["id"],
    label=NiA["object_type"],
    group=ObjectIds.index(NiA["object_id"]),
    type=N[i]["type"],
    objectid=NiA["object_id"],
    objecttype=NiA["object_type"],
    shape="box")

# %%
#G.nodes.get(0)
#G.nodes["EAAAAAAAABQTzQnhPSW2rhQAAADuv4NsAQAAAAAAAAA="]

# %%
#[(Nodes[i]["annotations"]["object_type"],Nodes[i]["annotations"]["object_id"]) for i in range(len(Nodes))]
for n in G.nodes:
    #n.shape = "box"
    pass

# %%
for i in range(len(Edges)):
    G.add_edge(Edges[i]["from"],Edges[i]["to"],annotations=Edges[i]["annotations"],label=Edges[i]["annotations"]["relation_type"])

# %%
from pyvis import network as pvnet

def plot_g_pyviz(G, name='out.html', height='700px', width='700px'):
    g = G.copy() # some attributes added to nodes
    net = pvnet.Network(notebook=True, directed=True, height=height, width=width,filter_menu=False)
    opts = '''
        var options = {
          "physics": {
            "forceAtlas2Based": {
              "gravitationalConstant": -100,
              "centralGravity": 0.11,
              "springLength": 100,
              "springConstant": 0.09,
              "avoidOverlap": 1
            },
            "minVelocity": 0.75,
            "solver": "HierachicalRepulsion",
            "timestep": 0.22
          }
        }
    '''

    opts2 = '''
        var options = {
          "physics": {
            "forceAtlas2Based": {
              "gravitationalConstant": -100,
              "centralGravity": 0.11,
              "springLength": 100,
              "springConstant": 0.09,
              "avoidOverlap": 1
            },
            "minVelocity": 1000,
            "solver": "BarnesHut",
            "timestep": 0.22
          }
        }
    '''
    

    net.set_options(opts2)
    # uncomment this to play with layout
    # net.show_buttons(filter_=['physics'])
    net.from_nx(g)
    return net.show(name)

plot_g_pyviz(G)
# Out:
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.
#         <iframe
#             width="700px"
#             height="700px"
#             src="out.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
with open("fork.cytoscape.json", "w") as file1:
    # Writing data to a file
    #file1.write(nx.cytoscape_data(G))
    json.dump(nx.cytoscape_data(G),file1)

# %%
from networkx.algorithms import isomorphism
# Out:
# {'data': [],
#  'directed': True,
#  'multigraph': True,
#  'elements': {'nodes': [{'data': {'label': 'machine',
#      'group': 0,
#      'type': 'Entity',
#      'objectid': '12589290756059548947',
#      'objecttype': 'machine',
#      'objectname': 'EAAAAAAAABQTzQnhPSW2rhQAAADuv4NsAQAAAAAAAAA=',
#      'shape': 'box',
#      'id': 'machine',
#      'value': 'machine',
#      'name': 'machine'}},
#    {'data': {'label': 'task',
#      'group': 4,
#      'type': 'Activity',
#      'objectid': '117724',
#      'objecttype': 'task',
#      'objectname': 'AQAAAAAAAEDcywEAAAAAABQAAADuv4NsAQAAAAAAAAA=',
#      'shape': 'box',
#      'id': 'task',
#      'value': 'task',
#      'name': 'task'}},
#    {'data': {'label': 'process_memory',
#      'group': 3,
#      'type': 'Entity',
#      'objectid': '117723',
#      'objecttype': 'process_memory',
#      'objectname': 'AAAIAAAAACDbywEAAAAAABQAAADuv4NsAQAAAAAAAAA=',
#      'shape': 'box',
#      'id': 'process_memory',
#      'value': 'process_memory',
#      'name': 'process_memory'}},
#    {'data': {'label': 'file',
#      'group': 5,
#      'type': 'Entity',
#      'objectid': '117725',
#      'objecttype': 'file',
#      'objectname': 'AAEAAAAAACDdywEAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#      'shape': 'box',
#      'id': 'file',
#      'value': 'file',
#      'name': 'file'}},
#    {'data': {'label': 'path',
#      'group': 7,
#      'type': 'Entity',
#      'objectid': '1556068040246191005',
#      'objecttype': 'path',
#      'objectname': 'AABAAAAAACSdYzZho0OYFRQAAADuv4NsAAAAAAAAAAA=',
#      'shape': 'box',
#      'id': 'path',
#      'value': 'path',
#      'name': 'path'}},
#    {'data': {'id': 'AQAAAAAAAEDXywEAAAAAABQAAADuv4NsAwAAAAAAAAA=',
#      'value': 'AQAAAAAAAEDXywEAAAAAABQAAADuv4NsAwAAAAAAAAA=',
#      'name': 'AQAAAAAAAEDXywEAAAAAABQAAADuv4NsAwAAAAAAAAA='}},
#    {'data': {'id': 'AQAAAAAAAEDXywEAAAAAABQAAADuv4NsAgAAAAAAAAA=',
#      'value': 'AQAAAAAAAEDXywEAAAAAABQAAADuv4NsAgAAAAAAAAA=',
#      'name': 'AQAAAAAAAEDXywEAAAAAABQAAADuv4NsAgAAAAAAAAA='}},
#    {'data': {'id': 'AQAAAAAAAEDXywEAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#      'value': 'AQAAAAAAAEDXywEAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#      'name': 'AQAAAAAAAEDXywEAAAAAABQAAADuv4NsAAAAAAAAAAA='}},
#    {'data': {'id': 'AAAIAAAAACDYywEAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#      'value': 'AAAIAAAAACDYywEAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#      'name': 'AAAIAAAAACDYywEAAAAAABQAAADuv4NsAAAAAAAAAAA='}},
#    {'data': {'id': 'EAAAAAAAABQTzQnhPSW2rhQAAADuv4NsAQAAAAAAAAA=',
#      'value': 'EAAAAAAAABQTzQnhPSW2rhQAAADuv4NsAQAAAAAAAAA=',
#      'name': 'EAAAAAAAABQTzQnhPSW2rhQAAADuv4NsAQAAAAAAAAA='}},
#    {'data': {'id': 'AAAIAAAAACDbywEAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#      'value': 'AAAIAAAAACDbywEAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#      'name': 'AAAIAAAAACDbywEAAAAAABQAAADuv4NsAAAAAAAAAAA='}},
#    {'data': {'id': 'AABAAAAAACRJfzun1igzLxQAAADuv4NsAAAAAAAAAAA=',
#      'value': 'AABAAAAAACRJfzun1igzLxQAAADuv4NsAAAAAAAAAAA=',
#      'name': 'AABAAAAAACRJfzun1igzLxQAAADuv4NsAAAAAAAAAAA='}},
#    {'data': {'id': 'AQAAAAAAAEDXywEAAAAAABQAAADuv4NsAQAAAAAAAAA=',
#      'value': 'AQAAAAAAAEDXywEAAAAAABQAAADuv4NsAQAAAAAAAAA=',
#      'name': 'AQAAAAAAAEDXywEAAAAAABQAAADuv4NsAQAAAAAAAAA='}},
#    {'data': {'id': 'AQAAAAAAAEDcywEAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#      'value': 'AQAAAAAAAEDcywEAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#      'name': 'AQAAAAAAAEDcywEAAAAAABQAAADuv4NsAAAAAAAAAAA='}},
#    {'data': {'id': 'AAEAAAAAACDdywEAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#      'value': 'AAEAAAAAACDdywEAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#      'name': 'AAEAAAAAACDdywEAAAAAABQAAADuv4NsAAAAAAAAAAA='}},
#    {'data': {'id': 'AAAIAAAAACDYywEAAAAAABQAAADuv4NsAQAAAAAAAAA=',
#      'value': 'AAAIAAAAACDYywEAAAAAABQAAADuv4NsAQAAAAAAAAA=',
#      'name': 'AAAIAAAAACDYywEAAAAAABQAAADuv4NsAQAAAAAAAAA='}},
#    {'data': {'id': 'AQAAAAAAAEDcywEAAAAAABQAAADuv4NsAQAAAAAAAAA=',
#      'value': 'AQAAAAAAAEDcywEAAAAAABQAAADuv4NsAQAAAAAAAAA=',
#      'name': 'AQAAAAAAAEDcywEAAAAAABQAAADuv4NsAQAAAAAAAAA='}},
#    {'data': {'id': 'AAAIAAAAACDYywEAAAAAABQAAADuv4NsAgAAAAAAAAA=',
#      'value': 'AAAIAAAAACDYywEAAAAAABQAAADuv4NsAgAAAAAAAAA=',
#      'name': 'AAAIAAAAACDYywEAAAAAABQAAADuv4NsAgAAAAAAAAA='}},
#    {'data': {'id': 'AAAIAAAAACDbywEAAAAAABQAAADuv4NsAQAAAAAAAAA=',
#      'value': 'AAAIAAAAACDbywEAAAAAABQAAADuv4NsAQAAAAAAAAA=',
#      'name': 'AAAIAAAAACDbywEAAAAAABQAAADuv4NsAQAAAAAAAAA='}},
#    {'data': {'id': 'AABAAAAAACSdYzZho0OYFRQAAADuv4NsAAAAAAAAAAA=',
#      'value': 'AABAAAAAACSdYzZho0OYFRQAAADuv4NsAAAAAAAAAAA=',
#      'name': 'AABAAAAAACSdYzZho0OYFRQAAADuv4NsAAAAAAAAAAA='}}],
#   'edges': [{'data': {'annotations': {'id': 'BAAAAAAAEIANAAAAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#       'relation_id': '13',
#       'relation_type': 'terminate_task',
#       'boot_id': 20,
#       'cf:machine_id': 'cf:1820573678',
#       'cf:date': '2023:01:08T09:07:14',
#       'epoch': 2,
#       'jiffies': '4294785670',
#       'allowed': 'true',
#       'flags': '0',
#       'task_id': '85467',
#       'from_type': 'task',
#       'to_type': 'task'},
#      'label': 'terminate_task',
#      'source': 'AQAAAAAAAEDXywEAAAAAABQAAADuv4NsAwAAAAAAAAA=',
#      'target': 'AQAAAAAAAEDXywEAAAAAABQAAADuv4NsAgAAAAAAAAA=',
#      'key': 0}},
#    {'data': {'annotations': {'id': 'AgAAAAAAEIAJAAAAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#       'relation_id': '9',
#       'relation_type': 'version_activity',
#       'boot_id': 20,
#       'cf:machine_id': 'cf:1820573678',
#       'cf:date': '2023:01:08T09:07:14',
#       'epoch': 2,
#       'jiffies': '4294785661',
#       'allowed': 'true',
#       'flags': '0',
#       'task_id': '117719',
#       'from_type': 'task',
#       'to_type': 'task'},
#      'label': 'version_activity',
#      'source': 'AQAAAAAAAEDXywEAAAAAABQAAADuv4NsAgAAAAAAAAA=',
#      'target': 'AQAAAAAAAEDXywEAAAAAABQAAADuv4NsAQAAAAAAAAA=',
#      'key': 0}},
#    {'data': {'annotations': {'id': 'gAAAAAAAIIAKAAAAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#       'relation_id': '10',
#       'relation_type': 'open',
#       'boot_id': 20,
#       'cf:machine_id': 'cf:1820573678',
#       'cf:date': '2023:01:08T09:07:14',
#       'epoch': 2,
#       'jiffies': '4294785661',
#       'allowed': 'true',
#       'flags': '0',
#       'task_id': '117719',
#       'from_type': 'task',
#       'to_type': 'file'},
#      'label': 'open',
#      'source': 'AQAAAAAAAEDXywEAAAAAABQAAADuv4NsAgAAAAAAAAA=',
#      'target': 'AAEAAAAAACDdywEAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#      'key': 0}},
#    {'data': {'annotations': {'id': 'BAAAAAAAIIABAAAAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#       'relation_id': '1',
#       'relation_type': 'memory_read',
#       'boot_id': 20,
#       'cf:machine_id': 'cf:1820573678',
#       'cf:date': '2023:01:08T09:07:14',
#       'epoch': 2,
#       'jiffies': '4294785658',
#       'allowed': 'true',
#       'flags': '0',
#       'task_id': '117719',
#       'from_type': 'task',
#       'to_type': 'process_memory'},
#      'label': 'memory_read',
#      'source': 'AQAAAAAAAEDXywEAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#      'target': 'AAAIAAAAACDYywEAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#      'key': 0}},
#    {'data': {'annotations': {'id': 'AQAAAAAABIACAAAAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#       'relation_id': '2',
#       'relation_type': 'ran_on',
#       'boot_id': 20,
#       'cf:machine_id': 'cf:1820573678',
#       'cf:date': '2023:01:08T09:07:14',
#       'epoch': 2,
#       'jiffies': '4294785659',
#       'allowed': 'true',
#       'flags': '0',
#       'task_id': '117719',
#       'from_type': 'task',
#       'to_type': 'machine'},
#      'label': 'ran_on',
#      'source': 'AQAAAAAAAEDXywEAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#      'target': 'EAAAAAAAABQTzQnhPSW2rhQAAADuv4NsAQAAAAAAAAA=',
#      'key': 0}},
#    {'data': {'annotations': {'id': 'AQAAAAAAgIAFAAAAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#       'relation_id': '5',
#       'relation_type': 'named',
#       'boot_id': 20,
#       'cf:machine_id': 'cf:1820573678',
#       'cf:date': '2023:01:08T09:07:14',
#       'epoch': 2,
#       'jiffies': '4294785659',
#       'allowed': 'true',
#       'flags': '0',
#       'task_id': '117719',
#       'from_type': 'process_memory',
#       'to_type': 'path'},
#      'label': 'named',
#      'source': 'AAAIAAAAACDYywEAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#      'target': 'AABAAAAAACRJfzun1igzLxQAAADuv4NsAAAAAAAAAAA=',
#      'key': 0}},
#    {'data': {'annotations': {'id': 'AQAAAAAAQIADAAAAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#       'relation_id': '3',
#       'relation_type': 'clone_mem',
#       'boot_id': 20,
#       'cf:machine_id': 'cf:1820573678',
#       'cf:date': '2023:01:08T09:07:14',
#       'epoch': 2,
#       'jiffies': '4294785659',
#       'allowed': 'true',
#       'flags': '0',
#       'task_id': '117719',
#       'from_type': 'process_memory',
#       'to_type': 'task'},
#      'label': 'clone_mem',
#      'source': 'AAAIAAAAACDbywEAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#      'target': 'AQAAAAAAAEDXywEAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#      'key': 0}},
#    {'data': {'annotations': {'id': 'AQAAAAAAgIAEAAAAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#       'relation_id': '4',
#       'relation_type': 'named',
#       'boot_id': 20,
#       'cf:machine_id': 'cf:1820573678',
#       'cf:date': '2023:01:08T09:07:14',
#       'epoch': 2,
#       'jiffies': '4294785659',
#       'allowed': 'true',
#       'flags': '0',
#       'task_id': '117719',
#       'from_type': 'process_memory',
#       'to_type': 'path'},
#      'label': 'named',
#      'source': 'AAAIAAAAACDbywEAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#      'target': 'AABAAAAAACRJfzun1igzLxQAAADuv4NsAAAAAAAAAAA=',
#      'key': 0}},
#    {'data': {'annotations': {'id': 'AgAAAAAAEIAGAAAAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#       'relation_id': '6',
#       'relation_type': 'version_activity',
#       'boot_id': 20,
#       'cf:machine_id': 'cf:1820573678',
#       'cf:date': '2023:01:08T09:07:14',
#       'epoch': 2,
#       'jiffies': '4294785659',
#       'allowed': 'true',
#       'flags': '0',
#       'task_id': '117719',
#       'from_type': 'task',
#       'to_type': 'task'},
#      'label': 'version_activity',
#      'source': 'AQAAAAAAAEDXywEAAAAAABQAAADuv4NsAQAAAAAAAAA=',
#      'target': 'AQAAAAAAAEDXywEAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#      'key': 0}},
#    {'data': {'annotations': {'id': 'BAAAAAAAIIAHAAAAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#       'relation_id': '7',
#       'relation_type': 'memory_read',
#       'boot_id': 20,
#       'cf:machine_id': 'cf:1820573678',
#       'cf:date': '2023:01:08T09:07:14',
#       'epoch': 2,
#       'jiffies': '4294785659',
#       'allowed': 'true',
#       'flags': '1200000',
#       'task_id': '117719',
#       'from_type': 'task',
#       'to_type': 'process_memory'},
#      'label': 'memory_read',
#      'source': 'AQAAAAAAAEDXywEAAAAAABQAAADuv4NsAQAAAAAAAAA=',
#      'target': 'AAAIAAAAACDYywEAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#      'key': 0}},
#    {'data': {'annotations': {'id': 'AQAAAAAAEIAIAAAAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#       'relation_id': '8',
#       'relation_type': 'clone',
#       'boot_id': 20,
#       'cf:machine_id': 'cf:1820573678',
#       'cf:date': '2023:01:08T09:07:14',
#       'epoch': 2,
#       'jiffies': '4294785659',
#       'allowed': 'true',
#       'flags': '1200000',
#       'task_id': '117719',
#       'from_type': 'task',
#       'to_type': 'task'},
#      'label': 'clone',
#      'source': 'AQAAAAAAAEDcywEAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#      'target': 'AQAAAAAAAEDXywEAAAAAABQAAADuv4NsAQAAAAAAAAA=',
#      'key': 0}},
#    {'data': {'annotations': {'id': 'AQAAAAAAgIARAAAAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#       'relation_id': '17',
#       'relation_type': 'named',
#       'boot_id': 20,
#       'cf:machine_id': 'cf:1820573678',
#       'cf:date': '2023:01:08T09:07:21',
#       'epoch': 2,
#       'jiffies': '4294792904',
#       'allowed': 'true',
#       'flags': '0',
#       'task_id': '119324',
#       'from_type': 'file',
#       'to_type': 'path'},
#      'label': 'named',
#      'source': 'AAEAAAAAACDdywEAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#      'target': 'AABAAAAAACSdYzZho0OYFRQAAADuv4NsAAAAAAAAAAA=',
#      'key': 0}},
#    {'data': {'annotations': {'id': 'AgAAAAAAgIALAAAAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#       'relation_id': '11',
#       'relation_type': 'version_entity',
#       'boot_id': 20,
#       'cf:machine_id': 'cf:1820573678',
#       'cf:date': '2023:01:08T09:07:14',
#       'epoch': 2,
#       'jiffies': '4294785661',
#       'allowed': 'true',
#       'flags': '0',
#       'task_id': '117719',
#       'from_type': 'process_memory',
#       'to_type': 'process_memory'},
#      'label': 'version_entity',
#      'source': 'AAAIAAAAACDYywEAAAAAABQAAADuv4NsAQAAAAAAAAA=',
#      'target': 'AAAIAAAAACDYywEAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#      'key': 0}},
#    {'data': {'annotations': {'id': 'gAAAAAAAQIAMAAAAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#       'relation_id': '12',
#       'relation_type': 'memory_write',
#       'boot_id': 20,
#       'cf:machine_id': 'cf:1820573678',
#       'cf:date': '2023:01:08T09:07:14',
#       'epoch': 2,
#       'jiffies': '4294785661',
#       'allowed': 'true',
#       'flags': '0',
#       'task_id': '117719',
#       'from_type': 'process_memory',
#       'to_type': 'task'},
#      'label': 'memory_write',
#      'source': 'AAAIAAAAACDYywEAAAAAABQAAADuv4NsAQAAAAAAAAA=',
#      'target': 'AQAAAAAAAEDXywEAAAAAABQAAADuv4NsAgAAAAAAAAA=',
#      'key': 0}},
#    {'data': {'annotations': {'id': 'BAAAAAAAEIAOAAAAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#       'relation_id': '14',
#       'relation_type': 'terminate_task',
#       'boot_id': 20,
#       'cf:machine_id': 'cf:1820573678',
#       'cf:date': '2023:01:08T09:07:14',
#       'epoch': 2,
#       'jiffies': '4294785674',
#       'allowed': 'true',
#       'flags': '0',
#       'task_id': '85460',
#       'from_type': 'task',
#       'to_type': 'task'},
#      'label': 'terminate_task',
#      'source': 'AQAAAAAAAEDcywEAAAAAABQAAADuv4NsAQAAAAAAAAA=',
#      'target': 'AQAAAAAAAEDcywEAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#      'key': 0}},
#    {'data': {'annotations': {'id': 'ACAAAAAAgIAPAAAAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#       'relation_id': '15',
#       'relation_type': 'terminate_proc',
#       'boot_id': 20,
#       'cf:machine_id': 'cf:1820573678',
#       'cf:date': '2023:01:08T09:07:14',
#       'epoch': 2,
#       'jiffies': '4294785684',
#       'allowed': 'true',
#       'flags': '0',
#       'task_id': '38',
#       'from_type': 'process_memory',
#       'to_type': 'process_memory'},
#      'label': 'terminate_proc',
#      'source': 'AAAIAAAAACDYywEAAAAAABQAAADuv4NsAgAAAAAAAAA=',
#      'target': 'AAAIAAAAACDYywEAAAAAABQAAADuv4NsAQAAAAAAAAA=',
#      'key': 0}},
#    {'data': {'annotations': {'id': 'ACAAAAAAgIAQAAAAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#       'relation_id': '16',
#       'relation_type': 'terminate_proc',
#       'boot_id': 20,
#       'cf:machine_id': 'cf:1820573678',
#       'cf:date': '2023:01:08T09:07:14',
#       'epoch': 2,
#       'jiffies': '4294785684',
#       'allowed': 'true',
#       'flags': '0',
#       'task_id': '38',
#       'from_type': 'process_memory',
#       'to_type': 'process_memory'},
#      'label': 'terminate_proc',
#      'source': 'AAAIAAAAACDbywEAAAAAABQAAADuv4NsAQAAAAAAAAA=',
#      'target': 'AAAIAAAAACDbywEAAAAAABQAAADuv4NsAAAAAAAAAAA=',
#      'key': 0}}]}}
